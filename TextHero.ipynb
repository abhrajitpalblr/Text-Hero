# %%
#TextHero
#Under the hoods, Texthero makes use of multiple NLP and machine learning toolkits such as Gensim, NLTK, SpaCy and scikit-learn. You don't need to install them all separately, pip will take care of that.

#Texthero include tools for:

#Preprocess text data: it offers both out-of-the-box solutions but it's also flexible for custom-solutions.
#Natural Language Processing: keyphrases and keywords extraction, and named entity recognition.
#Text representation: TF-IDF, term frequency, and custom word-embeddings (wip)
#Vector space analysis: clustering (K-means, Meanshift, DBSAN and Hierarchical), topic modelling (wip) and interpretation.
#Text visualization: vector space visualization, place localization on maps (wip).

# %%
# !pip install TextHero
# Out:
# Requirement already satisfied: TextHero in c:\users\abhra\anaconda3\lib\site-packages (1.0.5)
# Requirement already satisfied: plotly-express in c:\users\abhra\anaconda3\lib\site-packages (from TextHero) (0.4.1)
# Requirement already satisfied: nltk in c:\users\abhra\anaconda3\lib\site-packages (from TextHero) (3.6.2)
# Requirement already satisfied: scikit-learn in c:\users\abhra\anaconda3\lib\site-packages (from TextHero) (0.23.2)
# Requirement already satisfied: numpy>=1.11 in c:\users\abhra\anaconda3\lib\site-packages (from plotly-express->TextHero) (1.19.2)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\abhra\anaconda3\lib\site-packages (from plotly-express->TextHero) (0.12.0)
# Requirement already satisfied: plotly>=4.1.0 in c:\users\abhra\anaconda3\lib\site-packages (from plotly-express->TextHero) (4.14.3)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\abhra\anaconda3\lib\site-packages (from plotly-express->TextHero) (1.2.4)
# Requirement already satisfied: patsy>=0.5 in c:\users\abhra\anaconda3\lib\site-packages (from plotly-express->TextHero) (0.5.1)
# Requirement already satisfied: scipy>=0.18 in c:\users\abhra\anaconda3\lib\site-packages (from plotly-express->TextHero) (1.5.2)
# Requirement already satisfied: tqdm in c:\users\abhra\anaconda3\lib\site-packages (from nltk->TextHero) (4.50.2)
# Requirement already satisfied: click in c:\users\abhra\anaconda3\lib\site-packages (from nltk->TextHero) (7.1.2)
# Requirement already satisfied: regex in c:\users\abhra\anaconda3\lib\site-packages (from nltk->TextHero) (2020.10.15)
# Requirement already satisfied: joblib in c:\users\abhra\anaconda3\lib\site-packages (from nltk->TextHero) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\abhra\anaconda3\lib\site-packages (from scikit-learn->TextHero) (2.1.0)
# Requirement already satisfied: six in c:\users\abhra\anaconda3\lib\site-packages (from plotly>=4.1.0->plotly-express->TextHero) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\abhra\anaconda3\lib\site-packages (from plotly>=4.1.0->plotly-express->TextHero) (1.3.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\abhra\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly-express->TextHero) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\abhra\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly-express->TextHero) (2020.1)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import texthero as hero

# %%
data=pd.read_csv('reuters.csv')
data.head()
# Out:
#                                        headline_text  category
# 0  Southern European bond yields hit multi-week lows         3
# 1  BRIEF-LG sells its entire stake in unit LG Lif...         6
# 2  BRIEF-Golden Wheel Tiandi says unit confirms s...         3
# 3  BRIEF-Sunshine 100 China Holdings Dec contract...         3
# 4  Euro zone stocks start 2017 with new one-year ...         3

# %%
#make it lower case
hero.preprocessing.lowercase(data['headline_text'])
# Out:
# 0      southern european bond yields hit multi-week lows
# 1      brief-lg sells its entire stake in unit lg lif...
# 2      brief-golden wheel tiandi says unit confirms s...
# 3      brief-sunshine 100 china holdings dec contract...
# 4      euro zone stocks start 2017 with new one-year ...
#                              ...
# 994    brief-htm international to issue 1st series se...
# 995    brief-revlon says expects to eliminate about 3...
# 996                          twitter's china chief quits
# 997    peru demands cash from odebrecht ahead of plea...
# 998            corrected-forex-dollar resumes its ascent
# Name: headline_text, Length: 999, dtype: object

# %%
#will remove all the punctuation
hero.preprocessing.remove_punctuation(data['headline_text'])
# Out:
# 0      Southern European bond yields hit multi week lows
# 1      BRIEF LG sells its entire stake in unit LG Lif...
# 2      BRIEF Golden Wheel Tiandi says unit confirms s...
# 3      BRIEF Sunshine 100 China Holdings Dec contract...
# 4      Euro zone stocks start 2017 with new one year ...
#                              ...
# 994    BRIEF HTM International to issue 1st series se...
# 995    BRIEF Revlon says expects to eliminate about 3...
# 996                          Twitter s China chief quits
# 997    Peru demands cash from Odebrecht ahead of plea...
# 998            CORRECTED FOREX Dollar resumes its ascent
# Name: headline_text, Length: 999, dtype: object

# %%
#remove stop words
hero.preprocessing.remove_stop_words(data['headline_text'])
# Out:
# 0      Southern European bond yields hit multi-week lows
# 1      BRIEF-LG sells  entire stake  unit LG Life Sci...
# 2      BRIEF-Golden Wheel Tiandi says unit confirms s...
# 3      BRIEF-Sunshine 100 China Holdings Dec contract...
# 4      Euro zone stocks start 2017  new one-year high...
#                              ...
# 994    BRIEF-HTM International  issue 1st series secu...
# 995    BRIEF-Revlon says expects  eliminate  350 posi...
# 996                           Twitter' China chief quits
# 997    Peru demands cash  Odebrecht ahead  plea deal ...
# 998               CORRECTED-FOREX-Dollar resumes  ascent
# Name: headline_text, Length: 999, dtype: object

# %%
#remove digit
hero.preprocessing.remove_digits(data['headline_text'])
# Out:
# 0      Southern European bond yields hit multi-week lows
# 1      BRIEF-LG sells its entire stake in unit LG Lif...
# 2      BRIEF-Golden Wheel Tiandi says unit confirms s...
# 3      BRIEF-Sunshine China Holdings Dec contracted s...
# 4      Euro zone stocks start with new one-year high....
#                              ...
# 994    BRIEF-HTM International to issue 1st series se...
# 995    BRIEF-Revlon says expects to eliminate about p...
# 996                          Twitter's China chief quits
# 997    Peru demands cash from Odebrecht ahead of plea...
# 998            CORRECTED-FOREX-Dollar resumes its ascent
# Name: headline_text, Length: 999, dtype: object

# %%
#Remove content within square brackets [] and the square brackets.
s = pd.Series("Texthero [is not a superhero!]")
hero.preprocessing.remove_square_brackets(s)
# Out:
# 0    Texthero
# dtype: object

# %%
data['pca'] = (
   data['headline_text']
   .pipe(hero.clean)
   .pipe(hero.do_tfidf)#vectorizing
   .pipe(hero.do_pca)
)
hero.scatterplot(data, 'pca', color='category', title="PCA BBC Sport news")
# Out:
# <div>                            <div id="eaabed65-45fd-47c8-9e0b-d9e22f9ab5e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e
 4, 0, 0, 3, 3, 3, 3, 3, 3, 3, 3, 0, 3, 3, 3, 3, 3, 3, 4, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 1, 3, 3, 3, 6, 3, 3, 4, 3, 3, 5, 1, 3, 4, 3, 4, 3, 3, 1, 3, 4, 3, 4, 3, 3, 3, 3, 3, 1, 3, 3, 1, 5, 1, 1, 1, 0, 3, 3, 3, 1, 4, 3, 3, 1, 0, 3, 3, 3, 3, 6, 3, 1, 5, 3, 4, 4, 3, 3, 5, 3, 3, 3, 4, 3, 6, 3, 3, 4, 4, 0, 3, 3, 4, 3, 3, 5, 5, 1, 3, 4, 5, 3, 3, 3, 4, 3, 3, 3, 3, 6, 3, 3, 3, 6, 0, 3, 4, 3, 5, 5, 5, 5, 3, 3, 3, 0, 4, 3, 3, 3, 4, 3, 4, 3, 3, 4, 3, 4, 6, 3, 6, 4, 3, 4, 3, 4, 3, 3, 3, 1, 3, 3, 3, 1, 4, 3, 4, 1, 1, 3, 3, 3, 4, 5, 3, 3, 3, 3, 5, 5, 3, 5, 4, 5, 3, 3, 5, 3, 3, 3, 3, 3, 3, 5, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 5, 3, 3, 4, 3, 5, 3, 3, 3, 5, 3, 3, 3, 3, 0, 0, 3, 3, 5, 5, 3, 5, 3, 3, 6, 0, 3, 5, 5, 3, 4, 3, 5, 3, 4, 6, 5, 3, 6, 3, 3, 6, 3, 3, 3, 5, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 5, 2, 3, 3, 3, 3, 1, 4, 0, 3, 3, 4, 3, 5, 0, 3, 3, 4, 3, 3, 3, 3, 3, 4, 5, 2, 4, 3, 3, 3, 2, 4, 3, 6, 3, 3, 3, 0, 3, 3, 3, 5, 4, 4, 3, 3, 3, 3, 3, 6, 3, 6, 3, 3, 3, 4, 6, 3, 6, 3, 4, 3, 4, 3, 3, 4, 5, 3, 3, 6, 5, 3, 5, 6, 6, 6, 3, 3, 0, 3, 3, 4, 4, 2, 6, 2, 3, 5, 0, 6, 3, 0, 3, 6, 3, 6, 4, 5, 3, 4, 4, 4, 3, 3, 3, 3, 4, 3, 3, 6, 3, 3, 3, 3, 5, 3, 3, 4, 3, 3, 4, 6, 3, 4, 3, 5, 3, 4, 3, 3, 1, 4, 6, 4, 3, 3, 3, 3, 3, 3, 6, 3, 0, 3, 1, 3, 3, 3, 3, 3, 3, 4, 3, 2, 3, 4, 3, 3, 3, 3, 3, 3, 3, 6, 3, 3, 3, 3, 3, 6, 4, 3, 3, 3, 3, 3, 3, 4, 3, 3], "coloraxis": "coloraxis", "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [-0.13011893957292034, 0.10973007727087981, 0.08886153325767929, 0.026443490803389997, -0.24312980394735884, -0.25750658996646353, 0.14123611240183173, 0.04095337224203906, -0.18702909823937547, -0.184865160 ...

# %%
data['tfidf'] = (
    data['headline_text']
    .pipe(hero.clean)
    .pipe(hero.do_tfidf)
)
### Kmeans

data['kmeans_labels'] = (
    data['tfidf']
    .pipe(hero.do_kmeans, n_clusters=5)
    .astype(str)
)

data['pca'] = data['tfidf'].pipe(hero.do_pca)

hero.scatterplot(data, 'pca', color='kmeans_labels', title="K-means BBC Sport news")
# Out:
# <div>                            <div id="51f0dc22-5c32-48f4-b101-c65b57c5f0a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51f0dc22-5c32-48f4-b101-c65b57c5f0a5")) {                    Plotly.newPlot(                        "51f0dc22-5c32-48f4-b101-c65b57c5f0a5",                        [{"hovertemplate": "kmeans_labels=0<br>x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "0", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "0", "orientation": "v", "showlegend": true, "type": "scatter", "x": [