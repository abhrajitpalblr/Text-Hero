# %% [markdown]
# ## TextHero

# %% [markdown]
# Under the hoods, Texthero makes use of multiple NLP and machine learning toolkits such as Gensim, NLTK, SpaCy and scikit-learn. You don't need to install them all separately, pip will take care of that.

# %% [markdown]
# Texthero include tools for:
#
# - Preprocess text data: it offers both out-of-the-box solutions but it's also flexible for custom-solutions.
# - Natural Language Processing: keyphrases and keywords extraction, and named entity recognition.
# - Text representation: TF-IDF, term frequency, and custom word-embeddings (wip)
# - Vector space analysis: clustering (K-means, Meanshift, DBSAN and Hierarchical), topic modelling (wip) and interpretation.
# - Text visualization: vector space visualization, place localization on maps (wip).

# %% [markdown]
# Supported representation algorithms:
#
# - Term frequency (count)
# - Term frequency-inverse document frequency (tfidf)
# *********************************
# Supported clustering algorithms:
# *********************************
# - K-means (kmeans)
# - Density-Based Spatial Clustering of Applications with Noise (dbscan)
# - Meanshift (meanshift)
# ********************************
# Supported dimensionality reduction algorithms:
# *******************************
#
# - Principal component analysis (pca)
# - t-distributed stochastic neighbor embedding (tsne)
# - Non-negative matrix factorization (nmf)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install texthero
# Out:
# Requirement already satisfied: texthero in c:\users\abhra\anaconda3\lib\site-packages (1.0.5)
# Requirement already satisfied: nltk in c:\users\abhra\anaconda3\lib\site-packages (from texthero) (3.6.2)
# Requirement already satisfied: scikit-learn in c:\users\abhra\anaconda3\lib\site-packages (from texthero) (0.23.2)
# Requirement already satisfied: plotly-express in c:\users\abhra\anaconda3\lib\site-packages (from texthero) (0.4.1)
# Requirement already satisfied: regex in c:\users\abhra\anaconda3\lib\site-packages (from nltk->texthero) (2020.10.15)
# Requirement already satisfied: tqdm in c:\users\abhra\anaconda3\lib\site-packages (from nltk->texthero) (4.50.2)
# Requirement already satisfied: click in c:\users\abhra\anaconda3\lib\site-packages (from nltk->texthero) (7.1.2)
# Requirement already satisfied: joblib in c:\users\abhra\anaconda3\lib\site-packages (from nltk->texthero) (0.17.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\abhra\anaconda3\lib\site-packages (from scikit-learn->texthero) (1.5.2)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\abhra\anaconda3\lib\site-packages (from scikit-learn->texthero) (1.19.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\abhra\anaconda3\lib\site-packages (from scikit-learn->texthero) (2.1.0)
# Requirement already satisfied: plotly>=4.1.0 in c:\users\abhra\anaconda3\lib\site-packages (from plotly-express->texthero) (4.14.3)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\abhra\anaconda3\lib\site-packages (from plotly-express->texthero) (0.12.0)
# Requirement already satisfied: patsy>=0.5 in c:\users\abhra\anaconda3\lib\site-packages (from plotly-express->texthero) (0.5.1)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\abhra\anaconda3\lib\site-packages (from plotly-express->texthero) (1.2.4)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\abhra\anaconda3\lib\site-packages (from plotly>=4.1.0->plotly-express->texthero) (1.3.3)
# Requirement already satisfied: six in c:\users\abhra\anaconda3\lib\site-packages (from plotly>=4.1.0->plotly-express->texthero) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\abhra\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly-express->texthero) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\abhra\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly-express->texthero) (2.8.1)

# %%
import texthero
help(texthero)
# Out:
# Help on package texthero:
#
# NAME
#     texthero - Texthero: python toolkit for text preprocessing, representation and visualization.
#
# PACKAGE CONTENTS
#     __about__
#     clustering
#     preprocessing
#     representation
#     statistics
#     texthero
#     version
#     visualization
#
# DATA
#     stopwords = <WordListCorpusReader in 'C:\\Users\\Abhra\\AppData\\Roami...
#
# VERSION
#     1.0.5
#
# FILE
#     c:\users\abhra\anaconda3\lib\site-packages\texthero\__init__.py

# %% [markdown]
# #### Text Preprocessing

# %%
import pandas as pd
text="Backgammon is one of the oldest known board games. Its history can be traced back nearly 5,000 years to archeological discoveries in the Middle East. It is a two player game where each player has (fifteen) checkers which move between 24 points according to the roll of two dice."
series=pd.Series(text)

# %%
series
# Out:
# 0    Backgammon is one of the oldest known board ga...
# dtype: object

# %%
import texthero as hero

hero.remove_digits(series)
# Out:
# 0    Backgammon is one of the oldest known board ga...
# dtype: object

# %%
#### Remove punctuations
hero.remove_punctuation(series)
# Out:
# 0    Backgammon is one of the oldest known board ga...
# dtype: object

# %%
#### Remove Brackets
hero.remove_brackets(series)
# Out:
# 0    Backgammon is one of the oldest known board ga...
# dtype: object

# %%
hero.remove_diacritics(series)
# Out:
# 0    Backgammon is one of the oldest known board ga...
# dtype: object

# %%
hero.remove_whitespace(series)
# Out:
# 0    Backgammon is one of the oldest known board ga...
# dtype: object

# %%
### Stopwords
hero.remove_stop_words(series)
# Out:
# 0    Backgammon  one   oldest known board games. It...
# dtype: object

# %%
hero.clean(series)
# Out:
# 0    backgammon one oldest known board games histor...
# dtype: object

# %%
df = pd.read_csv(
   "https://github.com/jbesomi/texthero/raw/master/dataset/bbcsport.csv"
)
df.head()
# Out:
#                                                 text      topic
# 0  Claxton hunting first major medal\n\nBritish h...  athletics
# 1  O'Sullivan could run in Worlds\n\nSonia O'Sull...  athletics
# 2  Greene sets sights on world title\n\nMaurice G...  athletics
# 3  IAAF launches fight against drugs\n\nThe IAAF ...  athletics
# 4  Dibaba breaks 5,000m world record\n\nEthiopia'...  athletics

# %%
###PCA
import texthero as hero
import pandas as pd

df = pd.read_csv(
   "https://github.com/jbesomi/texthero/raw/master/dataset/bbcsport.csv"
)

df['pca'] = (
   df['text']
   .pipe(hero.clean)
   .pipe(hero.do_tfidf)#vectorizing
   .pipe(hero.do_pca)
)
hero.scatterplot(df, 'pca', color='topic', title="PCA BBC Sport news")
# Out:
# <div>                            <div id="24359590-af41-445b-87bf-d81df7b961fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24359590-af41-445b-87bf-d81df7b961fe")) {                    Plotly.newPlot(                        "24359590-af41-445b-87bf-d81df7b961fe",                        [{"hovertemplate": "topic=athletics<br>x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "athletics", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "athletics", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.021837064492021573, -0.1078507980789952, 0.04752140853536325, 0.025562860091105987, -0.018278790528479666, -0.0077041913553843235, -0.07284465722016524, 0.07184600602627006, 0.0009697966025987403, 0.028103719864400658, 0.05804476927396856, 0.04356342720121758, 0.020351752761669027, 0.041625057414303016, -0.030516392791323583, -0.08840593781625887, 0.033554270773985345, -0.04653591705662901, 0.03505758034017312, 0.04356342720121758, -0.0007990611498064172, 0.018508309772180254, 0.04678498716417392, -0.010876328466453337, 0.01440543349762895, -0.033012902559345206, -0.021566789631074057, 0.09859522414526874, 0.017748352175189944, -0.017409784235763833, -0.02746089720599646, 0.02069122506994758, 0.07096076996014096, 0.07022264338981452, -0.03228427425857827, -0.04025453174450923, 0.029285193447018215, 0.0799855098950779, -0.05498921992890019, 0.0301423100792319, 0.04088754414036648, -0.005325178628868028, -0.07512068345638866, 0.05618068350862412, 0.02373687356153615, 0.11895973801384153, -0.0799316574990037, -0.011176721007204824, -0.06661729045151092, -0.11510395207926881, -0.13932300898022515, -0.0504132097386213, 0.007417900190052378, 0.04141148964920543, -0.01050711710765723, 0.07246950054651026, 0.06727161794316212, -0.00876444165101579, 0.09346335489926737, -0.034844585872611106, -0.04532247190841492, -0.051540220189073775, 0.07504683796608115, -0.05032731797184022, 0.029879751980826087, -0.03661389104594172, 0.04591722319856376, -0.05542450636662787, 0.015964023766221868, 0.08457175095003551, 0.03862365819331152, -0.0036169961186961292, 0.09707107787923432, 0.06557387689058351, -0.10604780679213024, -0.027527343537360246, -0.26577253496011083, 0.010508022483321954, -0.040528038974467884, -0.056602395203039585, -0.03992693639702631, -0.1563561963142271, -0.11295667597549582, -0.0504132097386213, 0.05329994359508677, 0.006884630599182997, -0.0039481088824230735, -0.06661729045151092, -0.03902291696730318, 0.06511579162906336, -0.010660329925693001, 0.14520601530403113, -0.04438756525661194, 0.05018435346087125, 0.032658145241663855, 0.07755674593221143, 0.02209314659814363, 0.05154224624929163, 0.10423201149140789, 0.15465095407293777, 0.0048404230735806094], "xaxis": "x", "y": [-0.25498467778003636, 0.012807528242805755, -0.24468334905976996, -0.2283714483856848, -0.21534703599357619, -0.20849560553262353, -0.1563855557782309, -0.10190074446655781, -0.29639220979379055, -0.3053710593893462, -0.06310465179977291, -0.3144120223477586, -0.20517052975798253, -0.15060747234762029, -0.2095494678907521, -0.2830045751741804, -0.13601210076512305, -0.22986561791877835, -0.3192451376481346, -0.3144120223477586, -0.2834975280123463, -0.09224877233559757, -0.15648514013274284, -0.25521072201225065, -0.3227766441408167, -0.2662291259485162, -0.301109641424129, -0.1384364903284816, -0.2988921054043786, -0.1860796031913622, -0.0763627653684594, -0.32312472035778217, -0.11309412385556883, -0.17266693321044704, -0.3395286180229183, -0.03635655406547475, -0.22079726621963197, -0.18101688709656139, -0.0007274837140517693, -0.17335669323976113, -0.2118576734644134, -0.25060388525094246, 0.016701933155398082, -0.21252030393211807, -0.25333357833561676, -0.1281630500478 ...

# %%
df
# Out:
#                                                   text      topic  \
# 0    Claxton hunting first major medal\n\nBritish h...  athletics
# 1    O'Sullivan could run in Worlds\n\nSonia O'Sull...  athletics
# 2    Greene sets sights on world title\n\nMaurice G...  athletics
# 3    IAAF launches fight against drugs\n\nThe IAAF ...  athletics
# 4    Dibaba breaks 5,000m world record\n\nEthiopia'...  athletics
# ..                                                 ...        ...
# 732  Agassi into second round in Dubai\n\nFourth se...     tennis
# 733  Mauresmo fights back to win title\n\nWorld num...     tennis
# 734  Federer wins title in Rotterdam\n\nWorld numbe...     tennis
# 735  GB players warned over security\n\nBritain's D...     tennis
# 736  Sharapova overcomes tough Molik\n\nWimbledon c...     tennis
#
#                                                pca
# 0     [0.021837064492021573, -0.25498467778003636]
# 1      [-0.1078507980789952, 0.012807528242805755]
# 2      [0.04752140853536325, -0.24468334905976996]
# 3      [0.025562860091105987, -0.2283714483856848]
# 4    [-0.018278790528479666, -0.21534703599357619]
# ..                                             ...
# 732   [-0.03931431828575104, -0.23077802100878952]
# 733    [-0.04133748439698744, -0.3684613853914394]
# 734   [-0.055367724732986026, -0.2622211584437157]
# 735    [0.11174055041341721, 0.030208444921598243]
# 736    [-0.08873146538757895, -0.3312403988869016]
#
# [737 rows x 3 columns]

# %%
import texthero as hero
import pandas as pd

df = pd.read_csv(
    "https://github.com/jbesomi/texthero/raw/master/dataset/bbcsport.csv"
)

df['tfidf'] = (
    df['text']
    .pipe(hero.clean)
    .pipe(hero.do_tfidf)
)
### Kmeans

df['kmeans_labels'] = (
    df['tfidf']
    .pipe(hero.do_kmeans, n_clusters=5)
    .astype(str)
)

df['pca'] = df['tfidf'].pipe(hero.do_pca)

hero.scatterplot(df, 'pca', color='kmeans_labels', title="K-means BBC Sport news")
# Out:
# <div>                            <div id="93034c0d-303d-4d15-8074-61c465ef5d7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("